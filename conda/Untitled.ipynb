# %%
os.system('mypy3.sh')
# Out:
# 0

# %%
os.system('te.sh')
# Out:
# 0

# %%
os.system('te2.sh')
# Out:
# 0

# %%
import os

# %%
# !p.py

# %%
os.system('p.py')
# Out:
# 0

# %%
print('hello me')
import pandas as pd
print(pd.__version__)
# Out:
# hello me
# 1.1.0

# %%
import requests

# %%
# Out:
# 100% [............................................................................] 732383 / 732383
# 'data.zip'

# %%
# !cd
# Out:
# C:\Users\timothee\Desktop\small_tasks\conda
